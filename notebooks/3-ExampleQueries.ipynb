# %% [markdown]
# # Example queries on COVID-19 Knowledge Graph

# %%
import os
from py2neo import Graph

# %%
graph = Graph(password="neo4jbinder")

# %% [markdown]
# ### How many people have died of COVID-19?

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[i:OCCURED_IN]->(:Country)
WHERE o.name = 'COVID-19'
RETURN sum(i.deaths) as Deaths
"""
graph.run(query).to_data_frame()
# Out:
#    Deaths
# 0    1117

# %% [markdown]
# ### How many patients are confirmed, have died, or have recovered by country?

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[i:OCCURED_IN]->(c:Country)
WHERE o.name = 'COVID-19'
RETURN c.name as Country, i.confirmed as Confirmed, i.deaths as Deaths, i.recovered as Recovered
ORDER BY i.confirmed DESC
"""
graph.run(query).to_data_frame()
# Out:
#                  Country  Confirmed  Deaths  Recovered
# 0                  China      44687    1115       5062
# 1                 Others        175       0          0
# 2              Hong Kong         50       1          1
# 3              Singapore         47       0          9
# 4               Thailand         33       0         10
# 5                  Japan         28       0          9
# 6            South Korea         28       0          7
# 7                 Taiwan         18       0          1
# 8               Malaysia         18       0          3
# 9                Germany         16       0          0
# 10             Australia         15       0          2
# 11               Vietnam         15       0          6
# 12                   USA         13       0          3
# 13                France         11       0          0
# 14                 Macau         10       0          2
# 15  United Arab Emirates          8       0          1
# 16        United Kingdom          8       0          0
# 17                Canada          7       0          0
# 18                 Italy          3       0          0
# 19                 India          3       0          0
# 20           Philippines          3       1          1
# 21                 Spain          2       0          0
# 22                Russia          2       0          2
# 23               Finland          1       0          1
# 24             Sri Lanka          1       0          1
# 25              Cambodia          1       0          1
# 26                 Nepal          1       0          1
# 27                Sweden          1       0          0
# 28               Belgium          1       0          0

# %% [markdown]
# ### Which pathogen causes the COVID-19 outbreak?

# %%
query = """
MATCH (p:Pathogen)-[:CAUSES]->(o:InfectiousDiseaseOutbreak)
WHERE o.name = 'COVID-19'
RETURN p.name as Pathogen, p.taxonomyId as TaxonomyId
"""
graph.run(query).to_data_frame()
# Out:
#                                Pathogen TaxonomyId
# 0  Wuhan seafood market pneumonia virus     269749

# %% [markdown]
# ### What are the known strains of the COVID-19 virus?

# %%
query = """
MATCH (s:Strain)<-[:HAS_STRAIN]-(:Pathogen)-[:CAUSES]->(o:InfectiousDiseaseOutbreak)
WHERE o.name = 'COVID-19'
RETURN s.name as Strain
"""
graph.run(query).to_data_frame()
# Out:
#                        Strain
# 0          Nonthaburi/61/2020
# 1        Japan/TY-WK-521/2020
# 2        Germany/BavPat1/2020
# 3           Korea/KCDC03/2020
# 4         Japan/AI/I-004/2020
# ..                        ...
# 96           HKU-SZ-007a_2020
# 97   Wuhan/IPBCAMS-WH-02/2019
# 98           HKU-SZ-007c_2020
# 99               USA/CA2/2020
# 100  Wuhan/IPBCAMS-WH-05/2020
#
# [101 rows x 1 columns]

# %% [markdown]
# ### Which strains are found in each state?

# %%
query = """
MATCH (st:State)<-[:FOUND_IN]-(s:Strain)<-[:HAS_STRAIN]-(:Pathogen)-[:CAUSES]->(o:InfectiousDiseaseOutbreak)
WHERE o.name = 'COVID-19'
RETURN st.name as State, s.name as Strain
ORDER BY st.name
"""
graph.run(query).to_data_frame()
# Out:
#          State                    Strain
# 0      Arizona              USA/AZ1/2020
# 1      Beijing  Beijing/IVDC-BJ-005/2020
# 2   California              USA/CA3/2020
# 3   California              USA/CA1/2020
# 4   California              USA/CA5/2020
# ..         ...                       ...
# 75   Wisconsin              USA/WI1/2020
# 76      Yunnan   Yunnan/IVDC-YN-003/2020
# 77    Zhejiang       Zhejiang/WZ-02/2020
# 78    Zhejiang  Zhejiang/Hangzhou-1/2020
# 79    Zhejiang       Zhejiang/WZ-01/2020
#
# [80 rows x 2 columns]

# %% [markdown]
# ### Which strain is the most deadly?
# Unfortunately, we can't answer that question. Patient data are not available for specific strains.

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[i:OCCURED_IN]->(st:State)<-[:FOUND_IN]-(s:Strain)
WHERE o.name = 'COVID-19' AND i.confirmed > 0 AND i.deaths > 0 AND i.recovered > 0
RETURN st.name as State,  s.name as Strain, i.confirmed as Confirmed, i.deaths as Death, i.recovered as Recovered, toFloat(i.deaths)/toFloat(i.confirmed) as `Death/Confirmed Ratio`, toFloat(i.deaths)/toFloat(i.recovered) as `Death/Recovered Ratio`
ORDER BY toFloat(i.deaths)/toFloat(i.recovered) DESC
"""
graph.run(query).to_data_frame()
# Out:
#         State                        Strain  Confirmed  Death  Recovered  \
# 0       Hubei                         WHU01      33366   1068       2686
# 1       Hubei         Wuhan/IVDC-HB-04/2020      33366   1068       2686
# 2       Hubei      Wuhan/IPBCAMS-WH-01/2019      33366   1068       2686
# 3       Hubei                         WHU02      33366   1068       2686
# 4       Hubei      Wuhan/IPBCAMS-WH-04/2019      33366   1068       2686
# 5       Hubei               Wuhan-Hu-1/2019      33366   1068       2686
# 6       Hubei              Wuhan/WIV06/2019      33366   1068       2686
# 7       Hubei  Wuhan/IVDC-HB-envF13-21/2020      33366   1068       2686
# 8       Hubei               Wuhan/WH01/2019      33366   1068       2686
# 9       Hubei               Wuhan/WH05/2020      33366   1068       2686
# 10      Hubei              Wuhan/WIV04/2019      33366   1068       2686
# 11      Hubei         Wuhan/IVDC-HB-05/2019      33366   1068       2686
# 12      Hubei      Wuhan/IPBCAMS-WH-03/2019      33366   1068       2686
# 13      Hubei      Wuhan/IPBCAMS-WH-05/2020      33366   1068       2686
# 14      Hubei        Wuhan/HBCDC-HB-01/2019      33366   1068       2686
# 15      Hubei  Wuhan/IVDC-HB-envF13-20/2020      33366   1068       2686
# 16      Hubei              Wuhan/WIV05/2019      33366   1068       2686
# 17      Hubei              Wuhan/WIV07/2019      33366   1068       2686
# 18      Hubei               Wuhan/WH03/2020      33366   1068       2686
# 19      Hubei               Wuhan/WH04/2020      33366   1068       2686
# 20      Hubei         Wuhan/IVDC-HB-01/2019      33366   1068       2686
# 21      Hubei              Wuhan/WIV02/2019      33366   1068       2686
# 22      Hubei      Wuhan/IPBCAMS-WH-02/2019      33366   1068       2686
# 23    Beijing      Beijing/IVDC-BJ-005/2020        352      3         56
# 24  Chongqing           Chongqing/ZX01/2020        509      3         87
# 25  Chongqing           Chongqing/YC01/2020        509      3         87
# 26  Chongqing    Chongqing/IVDC-CQ-001/2020        509      3         87
# 27   Shandong     Shandong/IVDC-SD-001/2020        497      2         92
# 28    Sichuan      Sichuan/IVDC-SC-001/2020        436      1         92
# 29    Jiangxi      Jiangxi/IVDC-JX-002/2020        844      1        152
# 30  Guangdong               HKU-SZ-005_2020       1219      1        275
# 31  Guangdong              HKU-SZ-007a_2020       1219      1        275
# 32  Guangdong        Guangdong/20SF201/2020       1219      1        275
# 33  Guangdong               HKU-SZ-001_2020       1219      1        275
# 34  Guangdong           Foshan/20SF207/2020       1219      1        275
# 35  Guangdong        Guangzhou/20SF206/2020       1219      1        275
# 36  Guangdong           Foshan/20SF211/2020       1219      1        275
# 37  Guangdong        Guangdong/20SF040/2020       1219      1        275
# 38  Guangdong        Guangdong/20SF012/2020       1219      1        275
# 39  Guangdong              HKU-SZ-007c_2020       1219      1        275
# 40  Guangdong        Shenzhen/SZTH-003/2020       1219      1        275
# 41  Guangdong              HKU-SZ-005b_2020       1219      1        275
# 42  Guangdong        Guangdong/20SF014/2020       1219      1        275
# 43  Guangdong        Shenzhen/SZTH-002/2020       1219      1        275
# 44  Guangdong              HKU-SZ-002b_2020       1219      1        275
# 45  Guangdong              HKU-SZ-007b_2020       1219      1        275
# 46  Guangdong        Shenzhen/SZTH-004/2020       1219      1        275
# 47  Guangdong           Foshan/20SF210/2020       1219      1        275
# 48  Guangdong              HKU-SZ-002a_2020       1219      1        275
# 49  Guangdong        Shenzhen/SZTH-001/2020       1219      1        275
# 50  Guangdong               HKU-SZ-004_2020       1219      1        275
# 51  Guangdong        Guangdong/20SF013/2020       1219      1        275
# 52  Guangdong        Guangdong/20SF028/2020       1219      1        275
# 53  Guangdong        Guangdong/20SF174/2020       1219      1        275
# 54  Guangdong        Guangdong/20SF025/2020       1219      1        275
#
#     Death/Confirmed Ratio  Death/Recovered Ratio
# 0                0.032009               0.397617
# 1                0.032009               0.397617
# 2                0.032009               0.397617
# 3                0.032009               0.397617
# 4                0.032009               0.397617
# 5                0.032009               0.397617
# 6                0.032009               0.397617
# 7                0.032009               0.397617
# 8                0.032009               0.397617
# 9                0.032009               0.397617
# 10               0.032009               0.397617
# 11               0.032009               0.397617
# 12               0.032009               0.397617
# 13               0.032009               0.397617
# 14               0.032009               0.397617
# 15               0.032009               0.397617
# 16               0.032009               0.397617
# 17               0.032009               0.397617
# 18               0.032009               0.397617
# 19               0.032009               0.397617
# 20               0.032009               0.397617
# 21               0.032009               0.397617
# 22               0.032009               0.397617
# 23               0.008523               0.053571
# 24               0.005894               0.034483
# 25               0.005894               0.034483
# 26               0.005894               0.034483
# 27               0.004024               0.021739
# 28               0.002294               0.010870
# 29               0.001185               0.006579
# 30               0.000820               0.003636
# 31               0.000820               0.003636
# 32               0.000820               0.003636
# 33               0.000820               0.003636
# 34               0.000820               0.003636
# 35               0.000820               0.003636
# 36               0.000820               0.003636
# 37               0.000820               0.003636
# 38               0.000820               0.003636
# 39               0.000820               0.003636
# 40               0.000820               0.003636
# 41               0.000820               0.003636
# 42               0.000820               0.003636
# 43               0.000820               0.003636
# 44               0.000820               0.003636
# 45               0.000820               0.003636
# 46               0.000820               0.003636
# 47               0.000820               0.003636
# 48               0.000820               0.003636
# 49               0.000820               0.003636
# 50               0.000820               0.003636
# 51               0.000820               0.003636
# 52               0.000820               0.003636
# 53               0.000820               0.003636
# 54               0.000820               0.003636

# %% [markdown]
# ### What is the number of confirmed cases in China as function of the distance from Hubei?
# There is no clear relationship based on distance. We need to include other factors, such as travel information.

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[i:OCCURED_IN]->(st:State)-[:LOCATED_IN]->(k:Country)
MATCH (ref:State)
WHERE ref.name = "Hubei" AND k.name = 'China' AND o.name = 'COVID-19'
RETURN st.name as State, round(distance(ref.location, st.location)/1000.0) AS `Distance [km]`, i.confirmed as Confirmed
ORDER by round(distance(ref.location, st.location))
"""
graph.run(query).to_data_frame()
# Out:
#              State  Distance [km]  Confirmed
# 0            Hubei            0.0      33366
# 1            Henan          347.0       1135
# 2            Hunan          379.0        946
# 3        Chongqing          434.0        509
# 4            Anhui          480.0        889
# 5          Jiangxi          502.0        844
# 6          Shaanxi          566.0        225
# 7          Guizhou          701.0        133
# 8          Jiangsu          714.0        543
# 9           Shanxi          735.0        124
# 10        Zhejiang          780.0       1131
# 11          Fujian          781.0        272
# 12        Shandong          808.0        497
# 13           Hebei          813.0        251
# 14       Guangdong          858.0       1219
# 15         Guangxi          867.0        222
# 16        Shanghai          876.0        311
# 17         Ningxia          898.0         58
# 18         Sichuan          915.0        436
# 19           Gansu          966.0         86
# 20         Tianjin         1034.0        112
# 21         Beijing         1091.0        352
# 22          Yunnan         1252.0        154
# 23          Hainan         1336.0        157
# 24  Inner Mongolia         1468.0         60
# 25        Liaoning         1475.0        116
# 26         Qinghai         1596.0         18
# 27           Jilin         1869.0         83
# 28           Tibet         2249.0          1
# 29    Heilongjiang         2295.0        378
# 30        Xinjiang         2672.0         59
