# %% [markdown]
# # Example queries on COVID-19 Knowledge Graph

# %%
import os
import pandas as pd
from py2neo import Graph

# %%
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columsns

# %%
graph = Graph(password="neo4jbinder")

# %% [markdown]
# ### List coronavirus outbreaks

# %%
query = """
MATCH (p:Pathogen)-[:CAUSES]->(o:Outbreak)
RETURN p.acronym as acronym, p.name as pathogen, p.taxonomy_id as taxonomy_id, o.name as outbreak, o.start_date as start_date
"""
graph.run(query).to_data_frame()
# Out:
#       acronym                                           pathogen taxonomy_id  \
# 0  SARS-CoV-2    Severe acute respiratory syndrome coronavirus 2     2697049
# 1    MERS-CoV  Middle East respiratory syndrome-related coron...     1335626
# 2    SARS-CoV  Severe acute respiratory syndrome-related coro...      694009
#
#    outbreak start_date
# 0  COVID-19       2019
# 1      MERS       2012
# 2      SARS       2003

# %% [markdown]
# ### List person demographics and strain information for California

# %%
query = """
MATCH (a:Admin1)<-[:LOCATED_IN]-(p:Person)-[:CARRIES]->(s:Strain)
WHERE a.name = 'California'
RETURN p.age as age, p.sex as sex, p.exposure_location as exposure_location, s.name as strain
"""
graph.run(query).to_data_frame().head(100)
# Out:
#      age     sex exposure_location                strain
# 0     46  Female        California          USA/CA9/2020
# 1     51  Female        California          USA/CA8/2020
# 2     56  Female             Hubei          USA/CA7/2020
# 3     44    Male             Hubei          USA/CA6/2020
# 4     54  Female             Hubei          USA/CA5/2020
# 5     57  Female        California          USA/CA4/2020
# 6     57    Male        California          USA/CA3/2020
# 7     54    Male             Hubei          USA/CA2/2020
# 8     38    Male             Hubei          USA/CA1/2020
# 9   None    None        California    USA/CA-PC101P/2020
# 10  None    None        California  USA/CA-CDPH-UC4/2020
# 11  None    None        California  USA/CA-CDPH-UC3/2020
# 12  None    None        California  USA/CA-CDPH-UC2/2020

# %% [markdown]
# ### Find persons that where infected outside their living area

# %%
query = """
MATCH (c:Admin1)<-[:LOCATED_IN]-(p:Person)-[:CARRIES]->(s:Strain)
WHERE c.name <> p.exposure_location
RETURN c.name as `state/province`, p.age as age, p.sex as sex, p.exposure_location as exposure_location, s.name as strain
ORDER BY p.exposure_location
"""
graph.run(query).to_data_frame()
# Out:
#         state/province   age     sex exposure_location  \
# 0            Minnesota  None    None    Grand Princess
# 1            Minnesota  None    None    Grand Princess
# 2      New South Wales    53    Male             Hubei
# 3      New South Wales    43    Male             Hubei
# 4           Queensland    44    Male             Hubei
# 5             Victoria    50    Male             Hubei
# 6             Flanders    54    Male             Hubei
# 7        Sihanoukville    60    Male             Hubei
# 8              Ontario  None    Male             Hubei
# 9              Ontario    56    Male             Hubei
# 10             England    27  Female             Hubei
# 11             England    23    Male             Hubei
# 12             England    50  Female             Hubei
# 13             Finland    32  Female             Hubei
# 14       Ile de France    47  Female             Hubei
# 15            Zhejiang    32    Male             Hubei
# 16            Zhejiang    32    Male             Hubei
# 17               Lazio    66  Female             Hubei
# 18               Lazio    66  Female             Hubei
# 19           Kathmandu    32    Male             Hubei
# 20          Nonthaburi    74  Female             Hubei
# 21          Nonthaburi    61  Female             Hubei
# 22           Singapore    31  Female             Hubei
# 23           Singapore    66    Male             Hubei
# 24         South Korea  None    None             Hubei
# 25              Taiwan    45    Male             Hubei
# 26              Taiwan    50  Female             Hubei
# 27             Arizona    26    Male             Hubei
# 28          California    56  Female             Hubei
# 29          California    44    Male             Hubei
# 30          California    54  Female             Hubei
# 31          California    54    Male             Hubei
# 32          California    38    Male             Hubei
# 33            Illinois    68    Male             Hubei
# 34            Illinois    63  Female             Hubei
# 35       Massachusetts    21    Male             Hubei
# 36               Texas    50  Female             Hubei
# 37          Washington  None    Male             Hubei
# 38           Wisconsin    52  Female             Hubei
# 39           Thanh Hoa    25  Female             Hubei
# 40     New South Wales    81    Male              Iran
# 41     New South Wales    31    Male              Iran
# 42     New South Wales    38    Male              Iran
# 43     New South Wales    51  Female              Iran
# 44     New South Wales    43    Male              Iran
# 45    British Columbia    35  Female              Iran
# 46             Finland    29  Female              Iran
# 47             Bavaria    40  Female              Iran
# 48            Auckland  None  Female              Iran
# 49            New York    39  Female              Iran
# 50           Sao Paulo    13  Female             Italy
# 51      Usti nad Labem    44    Male             Italy
# 52             Finland    23  Female             Italy
# 53            Helsinki    59    Male             Italy
# 54               Lagos  None    Male             Italy
# 55           Sao Paulo    32    Male          Lombardy
# 56           Sao Paulo    61    Male          Lombardy
# 57            Helsinki    24  Female          Lombardy
# 58  Baden-Wuerttemberg  None    None          Lombardy
# 59         Mexico City    35    Male          Lombardy
# 60              Zurich    26  Female          Lombardy
# 61              Zurich    27    Male          Lombardy
# 62              Geneva    30    Male          Lombardy
# 63              Geneva    28    Male          Lombardy
# 64          Washington    58  Female       South Korea
#
#                                strain
# 0                   USA/MN3-MDH3/2020
# 1                   USA/MN1-MDH1/2020
# 2                       Sydney/2/2020
# 3                Australia/NSW01/2020
# 4                Australia/QLD01/2020
# 5                Australia/VIC01/2020
# 6              Belgium/GHB-03021/2020
# 7                  Cambodia/0012/2020
# 8              Canada/ON-VIDO-01/2020
# 9              Canada/ON-PHL2445/2020
# 10                   England/09c/2020
# 11                    England/02/2020
# 12                    England/01/2020
# 13                     Finland/1/2020
# 14                France/IDF0515/2020
# 15            Hangzhou/HZCDC0001/2020
# 16                 Hangzhou/HZ-1/2020
# 17               Italy/INMI1-isl/2020
# 18                Italy/INMI1-cs/2020
# 19                      Nepal/61/2020
# 20                 Nonthaburi/74/2020
# 21                 Nonthaburi/61/2020
# 22                   Singapore/4/2020
# 23                   Singapore/1/2020
# 24              SouthKorea/SNU01/2020
# 25                  Taiwan/NTU02/2020
# 26                  Taiwan/NTU01/2020
# 27                       USA/AZ1/2020
# 28                       USA/CA7/2020
# 29                       USA/CA6/2020
# 30                       USA/CA5/2020
# 31                       USA/CA2/2020
# 32                       USA/CA1/2020
# 33                       USA/IL2/2020
# 34                       USA/IL1/2020
# 35                       USA/MA1/2020
# 36                       USA/TX1/2020
# 37                       USA/WA1/2020
# 38                       USA/WI1/2020
# 39            Vietnam/VR03-38142/2020
# 40               Australia/NSW13/2020
# 41               Australia/NSW12/2020
# 42               Australia/NSW11/2020
# 43               Australia/NSW06/2020
# 44               Australia/NSW05/2020
# 45              Canada/BC_37_0-2/2020
# 46               Finland/FIN-266/2020
# 47               Germany/BavPat2/2020
# 48                 NewZealand/01/2020
# 49               USA/NY1-PV08001/2020
# 50                Brazil/SPBR-04/2020
# 51             CzechRepublic/951/2020
# 52               Finland/FIN-114/2020
# 53          Finland/FIN03032020C/2020
# 54               Nigeria/Lagos01/2020
# 55                Brazil/SPBR-02/2020
# 56                Brazil/SPBR-01/2020
# 57                Finland/FIN-25/2020
# 58  Germany/Baden-Wuerttemberg-1/2020
# 59          Mexico/CDMX/InDRE_01/2020
# 60        Switzerland/1000477797/2020
# 61        Switzerland/1000477796/2020
# 62            Switzerland/GE9586/2020
# 63            Switzerland/GE3895/2020
# 64                   USA/WA3-UW1/2020
