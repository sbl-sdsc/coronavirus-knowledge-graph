# %% [markdown]
# # Example queries on COVID-19 Knowledge Graph

# %%
import os
from py2neo import Graph

# %%
graph = Graph(password="neo4jbinder")

# %% [markdown]
# ### How many people have died of COVID-19?

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[i:OCCURED_IN]->(:Country)
WHERE o.name = 'COVID-19'
RETURN sum(i.deaths) as Deaths
"""
graph.run(query).to_data_frame()
# Out:
#    Deaths
# 0    1368

# %% [markdown]
# ### How many patients are confirmed, have died, or have recovered by country?

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[i:OCCURED_IN]->(c:Country)
WHERE o.name = 'COVID-19'
RETURN c.name as Country, i.confirmed as Confirmed, i.deaths as Deaths, i.recovered as Recovered
ORDER BY i.confirmed DESC
"""
graph.run(query).to_data_frame()
# Out:
#                  Country  Confirmed  Deaths  Recovered
# 0                  China      59805    1366       5915
# 1                 Others        175       0          0
# 2              Singapore         50       0         15
# 3              Hong Kong         50       1          1
# 4               Thailand         33       0         10
# 5            South Korea         28       0          7
# 6                  Japan         28       0          9
# 7               Malaysia         18       0          3
# 8                 Taiwan         18       0          1
# 9                Germany         16       0          0
# 10             Australia         15       0          2
# 11               Vietnam         15       0          6
# 12                   USA         13       0          3
# 13                France         11       0          2
# 14                 Macau         10       0          2
# 15        United Kingdom          9       0          1
# 16  United Arab Emirates          8       0          1
# 17                Canada          7       0          1
# 18                 India          3       0          0
# 19           Philippines          3       1          1
# 20                 Italy          3       0          0
# 21                 Spain          2       0          0
# 22                Russia          2       0          2
# 23               Belgium          1       0          0
# 24             Sri Lanka          1       0          1
# 25               Finland          1       0          1
# 26                 Nepal          1       0          1
# 27              Cambodia          1       0          1
# 28                Sweden          1       0          0

# %% [markdown]
# ### Which pathogen causes the COVID-19 outbreak?

# %%
query = """
MATCH (p:Pathogen)-[:CAUSES]->(o:InfectiousDiseaseOutbreak)
WHERE o.name = 'COVID-19'
RETURN p.name as Pathogen, p.taxonomyId as TaxonomyId
"""
graph.run(query).to_data_frame()
# Out:
#                                Pathogen TaxonomyId
# 0  Wuhan seafood market pneumonia virus     269749

# %% [markdown]
# ### What are the known strains of the COVID-19 virus?

# %%
query = """
MATCH (s:Strain)<-[:HAS_STRAIN]-(:Pathogen)-[:CAUSES]->(o:InfectiousDiseaseOutbreak)
WHERE o.name = 'COVID-19'
RETURN s.name as Strain
"""
graph.run(query).to_data_frame()
# Out:
#                        Strain
# 0          Nonthaburi/74/2020
# 1            Singapore/3/2020
# 2         Japan/KY-V-029/2020
# 3         France/IDF0373/2020
# 4            Singapore/1/2020
# ..                        ...
# 96            HKU-SZ-004_2020
# 97            Wuhan-Hu-1/2019
# 98           HKU-SZ-005b_2020
# 99               USA/AZ1/2020
# 100  Wuhan/IPBCAMS-WH-02/2019
#
# [101 rows x 1 columns]

# %% [markdown]
# ### Which strains are found in each state?

# %%
query = """
MATCH (st:State)<-[:FOUND_IN]-(s:Strain)<-[:HAS_STRAIN]-(:Pathogen)-[:CAUSES]->(o:InfectiousDiseaseOutbreak)
WHERE o.name = 'COVID-19'
RETURN st.name as State, s.name as Strain
ORDER BY st.name
"""
graph.run(query).to_data_frame()
# Out:
#          State                    Strain
# 0      Arizona              USA/AZ1/2020
# 1      Beijing  Beijing/IVDC-BJ-005/2020
# 2   California              USA/CA1/2020
# 3   California              USA/CA6/2020
# 4   California              USA/CA2/2020
# ..         ...                       ...
# 75   Wisconsin              USA/WI1/2020
# 76      Yunnan   Yunnan/IVDC-YN-003/2020
# 77    Zhejiang       Zhejiang/WZ-01/2020
# 78    Zhejiang       Zhejiang/WZ-02/2020
# 79    Zhejiang  Zhejiang/Hangzhou-1/2020
#
# [80 rows x 2 columns]

# %% [markdown]
# ### Which strain is the most deadly?
# Unfortunately, we can't answer that question. Patient data are not available for specific strains.

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[i:OCCURED_IN]->(st:State)<-[:FOUND_IN]-(s:Strain)
WHERE o.name = 'COVID-19' AND i.confirmed > 0 AND i.deaths > 0 AND i.recovered > 0
RETURN st.name as State,  s.name as Strain, i.confirmed as Confirmed, i.deaths as Death, i.recovered as Recovered, toFloat(i.deaths)/toFloat(i.confirmed) as `Death/Confirmed Ratio`, toFloat(i.deaths)/toFloat(i.recovered) as `Death/Recovered Ratio`
ORDER BY toFloat(i.deaths)/toFloat(i.recovered) DESC
"""
graph.run(query).to_data_frame()
# Out:
#         State                        Strain  Confirmed  Death  Recovered  \
# 0       Hubei      Wuhan/IPBCAMS-WH-04/2019      48206   1310       3441
# 1       Hubei                         WHU02      48206   1310       3441
# 2       Hubei      Wuhan/IPBCAMS-WH-01/2019      48206   1310       3441
# 3       Hubei              Wuhan/WIV02/2019      48206   1310       3441
# 4       Hubei         Wuhan/IVDC-HB-04/2020      48206   1310       3441
# 5       Hubei         Wuhan/IVDC-HB-05/2019      48206   1310       3441
# 6       Hubei               Wuhan/WH01/2019      48206   1310       3441
# 7       Hubei               Wuhan/WH04/2020      48206   1310       3441
# 8       Hubei              Wuhan/WIV07/2019      48206   1310       3441
# 9       Hubei      Wuhan/IPBCAMS-WH-05/2020      48206   1310       3441
# 10      Hubei        Wuhan/HBCDC-HB-01/2019      48206   1310       3441
# 11      Hubei      Wuhan/IPBCAMS-WH-02/2019      48206   1310       3441
# 12      Hubei              Wuhan/WIV06/2019      48206   1310       3441
# 13      Hubei                         WHU01      48206   1310       3441
# 14      Hubei         Wuhan/IVDC-HB-01/2019      48206   1310       3441
# 15      Hubei               Wuhan/WH05/2020      48206   1310       3441
# 16      Hubei              Wuhan/WIV04/2019      48206   1310       3441
# 17      Hubei              Wuhan/WIV05/2019      48206   1310       3441
# 18      Hubei  Wuhan/IVDC-HB-envF13-20/2020      48206   1310       3441
# 19      Hubei  Wuhan/IVDC-HB-envF13-21/2020      48206   1310       3441
# 20      Hubei      Wuhan/IPBCAMS-WH-03/2019      48206   1310       3441
# 16               0.027175               0.380703
# 17               0.027175               0.380703
# 18               0.027175               0.380703
# 19               0.027175               0.380703
# 20               0.027175               0.380703
# 21               0.027175               0.380703
# 22               0.027175               0.380703
# 23               0.008197               0.044118
# 24               0.005792               0.029412
# 25               0.005792               0.029412
# 26               0.005792               0.029412
# 27               0.003953               0.020408
# 28               0.002217               0.010753
# 29               0.001612               0.007042
# 30               0.001612               0.007042
# 31               0.001612               0.007042
# 32               0.001612               0.007042
# 33               0.001612               0.007042
# 34               0.001612               0.007042
# 35               0.001612               0.007042
# 36               0.001612               0.007042
# 37               0.001612               0.007042
# 38               0.001612               0.007042
# 39               0.001612               0.007042
# 40               0.001612               0.007042
# 41               0.001612               0.007042
# 42               0.001612               0.007042
# 43               0.001612               0.007042
# 44               0.001612               0.007042
# 45               0.001612               0.007042
# 46               0.001612               0.007042
# 47               0.001612               0.007042
# 48               0.001612               0.007042
# 49               0.001612               0.007042
# 50               0.001612               0.007042
# 51               0.001612               0.007042
# 52               0.001612               0.007042
# 53               0.001612               0.007042
# 54               0.001147               0.005882

# %% [markdown]
# ### What is the number of confirmed cases in China as function of the distance from Hubei?
# There is no clear relationship based on distance. We need to include other factors, such as travel information.

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[i:OCCURED_IN]->(st:State)-[:LOCATED_IN]->(k:Country)
MATCH (ref:State)
WHERE ref.name = "Hubei" AND k.name = 'China' AND o.name = 'COVID-19'
RETURN st.name as State, round(distance(ref.location, st.location)/1000.0) AS `Distance [km]`, i.confirmed as Confirmed
ORDER by round(distance(ref.location, st.location))
"""
graph.run(query).to_data_frame()
# Out:
#              State  Distance [km]  Confirmed
# 0            Hubei            0.0      48206
# 1            Henan          347.0       1169
# 2            Hunan          379.0        968
# 3        Chongqing          434.0        518
# 4            Anhui          480.0        910
# 5          Jiangxi          502.0        872
# 6          Shaanxi          566.0        229
# 7          Guizhou          701.0        135
# 8          Jiangsu          714.0        570
# 9           Shanxi          735.0        126
# 10        Zhejiang          780.0       1145
# 11          Fujian          781.0        279
# 12        Shandong          808.0        506
# 13           Hebei          813.0        265
# 14       Guangdong          858.0       1241
# 15         Guangxi          867.0        222
# 16        Shanghai          876.0        313
# 17         Ningxia          898.0         64
# 18         Sichuan          915.0        451
# 19           Gansu          966.0         87
# 20         Tianjin         1034.0        113
# 21         Beijing         1091.0        366
# 22          Yunnan         1252.0        155
# 23          Hainan         1336.0        157
# 24  Inner Mongolia         1468.0         61
# 25        Liaoning         1475.0        116
# 26         Qinghai         1596.0         18
# 27           Jilin         1869.0         84
# 28           Tibet         2249.0          1
# 29    Heilongjiang         2295.0        395
# 30        Xinjiang         2672.0         63
