# %% [markdown]
# # Create Knowledge Graph for Novel Coronavirus (COVID-19) Outbreak¶

# %%
import os
from py2neo import Graph

# %% [markdown]
# ### Open Graph data base

# %%
graph = Graph(password="neo4jbinder")

# %% [markdown]
# Remove any existing nodes and relationships

# %%
graph.run("MATCH (n) DETACH DELETE n")

# %% [markdown]
# Make sure that the core entities are unique

# %%
graph.run("CREATE CONSTRAINT ON (c:City) ASSERT c.name IS UNIQUE")
graph.run("CREATE CONSTRAINT ON (s:State) ASSERT s.name IS UNIQUE")
graph.run("CREATE CONSTRAINT ON (k:Country) ASSERT k.name IS UNIQUE")
graph.run("CREATE CONSTRAINT ON (r:Strain) ASSERT r.name IS UNIQUE")
graph.run("CREATE CONSTRAINT ON (i:InfectiousDiseaseOutbreak) ASSERT i.name IS UNIQUE")
graph.run("CREATE CONSTRAINT ON (p:Pathogen) ASSERT p.name IS UNIQUE")

# %% [markdown]
# Get absolute path for data directory (LOAD CSV requires absolute path)

# %%
data_dir = os.path.abspath("../data")

# %% [markdown]
# ### Create City-level nodes and relationships

# %%
load_city = f"LOAD CSV WITH HEADERS FROM 'file:///{data_dir}/city_COVID-19.csv' AS e"
query = """
MERGE (c:City {name:e.City})
SET c.location = point({longitude: toFloat(e.Long), latitude: toFloat(e.Lat)})   
MERGE (s:State {name:e.State})
MERGE (k:Country {name:e.Country})
MERGE (o:InfectiousDiseaseOutbreak {name:e.Outbreak})
        
MERGE (c)-[:LOCATED_IN]->(s)
MERGE (s)-[:LOCATED_IN]->(k)
MERGE (o)-[i:OCCURED_IN {update:e.`Last Update`}]->(c)
SET i.confirmed = toInt(e.Confirmed),
    i.deaths = toInt(e.Deaths), 
    i.recovered = toInt(e.Recovered)
"""
graph.run(load_city + query)

# %% [markdown]
# #### Run some test queries

# %%
query = """
MATCH (c:City)-[l1:LOCATED_IN]->(s:State)-[l2:LOCATED_IN]->(k:Country)
RETURN c.name as City, c.location as Location, s.name as State, k.name as Country
"""
graph.run(query).to_data_frame()
# Out:
#                     City                        Location  \
# 0               Lackland             (-98.6134, 29.3829)
# 1      Santa Rosa County  (-86.9824, 30.769000000000002)
# 2           Hillsborough             (-82.3018, 27.9904)
# 3               Sarasota             (-82.5307, 27.3364)
# 4     Westchester County              (-73.7949, 41.122)
# 5          Queens County             (-73.7949, 40.7282)
# 6          New York City              (-74.006, 40.7128)
# 7            King County            (-122.3321, 47.6062)
# 8       Snohomish County             (-121.8339, 48.033)
# 9           Grant County            (-119.3732, 47.1981)
# 10  San Francisco County            (-122.4194, 37.7749)
# 11            San Benito            (-120.9876, 36.5761)
# 12         Placer County            (-120.8039, 39.0916)
# 13             San Mateo             (-122.3255, 37.563)
# 14         Orange County            (-117.8531, 33.7879)
# 15       Humboldt County             (-123.8695, 40.745)
# 16           Santa Clara            (-121.9552, 37.3541)
# 17      San Diego County            (-117.1611, 32.7157)
# 18     Sacramento County            (-121.3542, 38.4747)
# 19   Contra Costa County            (-121.9018, 37.8534)
# 20           Los Angeles            (-118.2437, 34.0522)
# 21              Berkeley             (-122.273, 37.8715)
# 22         Sonoma County             (-122.9888, 38.578)
# 23     Washington County             (-123.1386, 45.547)
# 24              Umatilla             (-118.7606, 45.775)
# 25          Clark County             (-115.094, 36.0796)
# 26           San Antonio             (-98.4936, 29.4241)
# 27         Harris County             (-95.3103, 29.7752)
# 28      Fort Bend County             (-95.8143, 29.5693)
# 29                 Omaha             (-95.9758, 41.2545)
# 30            Providence              (-71.4128, 41.824)
# 31         Fulton County             (-84.3963, 33.8034)
# 32           Cook County             (-87.6976, 41.7377)
# 33           Wake County             (-78.5661, 35.8032)
# 34                Boston             (-71.0589, 42.3601)
# 35        Norfolk County             (-71.1449, 42.1767)
# 36                Travis            (-121.9399, 38.2721)
# 37     Williamson County             (-86.8622, 35.9179)
# 38               Madison             (-89.4012, 43.0731)
# 39         Bergen County              (-74.077, 40.9263)
# 40                 Tempe              (-111.94, 33.4255)
# 41       Maricopa County            (-112.4291, 33.2918)
# 42        Grafton County   (-71.82600000000002, 43.9088)
# 43               Toronto             (-79.3832, 43.6532)
# 44                London             (-81.2453, 42.9849)
# 45              Montreal             (-73.5673, 45.5017)
#
#                                    State Country
# 0   Lackland, TX (From Diamond Princess)     USA
# 1                                Florida     USA
# 2                                Florida     USA
# 3                                Florida     USA
# 4                               New York     USA
# 5                               New York     USA
# 6                               New York     USA
# 7                             Washington     USA
# 8                             Washington     USA
# 9                             Washington     USA
# 10                            California     USA
# 11                            California     USA
# 12                            California     USA
# 13                            California     USA
# 14                            California     USA
# 15                            California     USA
# 16                            California     USA
# 17                            California     USA
# 18                            California     USA
# 19                            California     USA
# 20                            California     USA
# 21                            California     USA
# 22                            California     USA
# 23                                Oregon     USA
# 24                                Oregon     USA
# 25                                Nevada     USA
# 26                                 Texas     USA
# 27                                 Texas     USA
# 28                                 Texas     USA
# 29     Omaha, NE (From Diamond Princess)     USA
# 30                          Rhode Island     USA
# 31                               Georgia     USA
# 32                              Illinois     USA
# 33                        North Carolina     USA
# 34                         Massachusetts     USA
# 35                         Massachusetts     USA
# 36    Travis, CA (From Diamond Princess)     USA
# 37                             Tennessee     USA
# 38                             Wisconsin     USA
# 39                            New Jersey     USA
# 40                               Arizona     USA
# 41                               Arizona     USA
# 42                         New Hampshire     USA
# 43                               Ontario  Canada
# 44                               Ontario  Canada
# 45                                Quebec  Canada

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[l:OCCURED_IN]->(c:City)-[:LOCATED_IN]->(s:State)
RETURN  c.name as City, s.name as State, o.name as Outbreak, l.confirmed as Confirmed, l.deaths as Deaths, l.recovered as Recovered
"""
graph.run(query).to_data_frame()
# Out:
#                     City                                 State  Outbreak  \
# 0      Williamson County                             Tennessee  COVID-19
# 1          Bergen County                            New Jersey  COVID-19
# 2            Santa Clara                            California  COVID-19
# 3            Los Angeles                            California  COVID-19
# 4            Wake County                        North Carolina  COVID-19
# 5      Washington County                                Oregon  COVID-19
# 6                Toronto                               Ontario  COVID-19
# 7    Contra Costa County                            California  COVID-19
# 8                 London                               Ontario  COVID-19
# 9          Fulton County                               Georgia  COVID-19
# 10    Westchester County                              New York  COVID-19
# 11       Humboldt County                            California  COVID-19
# 12              Lackland  Lackland, TX (From Diamond Princess)  COVID-19
# 13      San Diego County                            California  COVID-19
# 14       Maricopa County                               Arizona  COVID-19
# 15                Travis    Travis, CA (From Diamond Princess)  COVID-19
# 16         Queens County                              New York  COVID-19
# 17          Clark County                                Nevada  COVID-19
# 18              Berkeley                            California  COVID-19
# 19         Harris County                                 Texas  COVID-19
# 20              Montreal                                Quebec  COVID-19
# 21                 Tempe                               Arizona  COVID-19
# 22         Orange County                            California  COVID-19
# 23               Madison                             Wisconsin  COVID-19
# 24           San Antonio                                 Texas  COVID-19
# 25                 Omaha     Omaha, NE (From Diamond Princess)  COVID-19
# 26                Boston                         Massachusetts  COVID-19
# 27            Providence                          Rhode Island  COVID-19
# 28         Sonoma County                            California  COVID-19
# 29            San Benito                            California  COVID-19
# 30          Hillsborough                               Florida  COVID-19
# 31  San Francisco County                            California  COVID-19
# 32     Santa Rosa County                               Florida  COVID-19
# 33           King County                            Washington  COVID-19
# 34              Umatilla                                Oregon  COVID-19
# 35        Grafton County                         New Hampshire  COVID-19
# 36        Norfolk County                         Massachusetts  COVID-19
# 37          Grant County                            Washington  COVID-19
# 38         New York City                              New York  COVID-19
# 39              Sarasota                               Florida  COVID-19
# 40     Sacramento County                            California  COVID-19
# 41         Placer County                            California  COVID-19
# 42           Cook County                              Illinois  COVID-19
# 43      Fort Bend County                                 Texas  COVID-19
# 44             San Mateo                            California  COVID-19
# 45      Snohomish County                            Washington  COVID-19
#
#     Confirmed  Deaths  Recovered
# 0           1       0          0
# 1           2       0          0
# 2          20       0          1
# 3          11       0          0
# 4           1       0          0
# 5           2       0          0
# 6          21       0          2
# 7           1       0          0
# 8           1       0          1
# 9           2       0          0
# 10         18       0          0
# 11          1       0          0
# 12          0       0          0
# 13          3       0          1
# 14          1       0          0
# 15          0       0          0
# 16          1       0          0
# 17          1       0          0
# 18          1       0          0
# 19          2       0          0
# 20          2       0          0
# 21          1       0          1
# 22          3       0          0
# 23          1       0          1
# 24          1       0          0
# 25          0       0          0
# 26          1       0          1
# 27          2       0          0
# 28          1       0          0
# 29          2       0          0
# 30          2       0          0
# 31          2       0          0
# 32          1       0          0
# 33         51      10          1
# 34          1       0          0
# 35          2       0          0
# 36          1       0          0
# 37          1       0          0
# 38          4       0          0
# 39          1       0          0
# 40          2       0          0
# 41          2       1          0
# 42          5       0          2
# 43          1       0          0
# 44          2       0          0
# 45         18       1          0

# %% [markdown]
# ## Create State-level nodes and relationships

# %%
load_state = f"LOAD CSV WITH HEADERS FROM 'file:///{data_dir}/state_COVID-19.csv' AS e" 
query = """
MERGE (s:State {name:e.State}) 
SET s.location = point({longitude: toFloat(e.Long), latitude: toFloat(e.Lat)})  
MERGE (k:Country {name:e.Country})
MERGE (o:InfectiousDiseaseOutbreak {name:e.Outbreak})
        
MERGE (s)-[:LOCATED_IN]->(k)
MERGE (o)-[i:OCCURED_IN {update:e.`Last Update`}]->(s)
SET i.confirmed = toInt(e.Confirmed),
    i.deaths = toInt(e.Deaths), 
    i.recovered = toInt(e.Recovered)
"""
graph.run(load_state + query)

# %% [markdown]
# #### Run a test query

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[l:OCCURED_IN]->(s:State)-[:LOCATED_IN]->(k:Country)
RETURN  s.name as State, s.location as Location, k.name as Country, o.name as Outbreak, l.confirmed as Confirmed, l.deaths as Deaths, l.recovered as Recovered
"""
graph.run(query).to_data_frame()
# Out:
#                                           State              Location  \
# 0                                     Hong Kong         (114.2, 22.3)
# 1                                         Macau     (113.55, 22.1667)
# 2                                        Taiwan         (121.0, 23.7)
# 3   Unassigned Location (From Diamond Princess)    (139.638, 35.4437)
# 4          Lackland, TX (From Diamond Princess)   (-98.6134, 29.3829)
# ..                                          ...                   ...
# 62                                     Victoria  (144.9631, -37.8136)
# 63                            Western Australia  (115.8605, -31.9505)
# 64                                   Queensland     (153.4, -28.0167)
# 65                              South Australia  (138.6007, -34.9285)
# 66                        From Diamond Princess    (139.638, 35.4437)
#
#       Country  Outbreak  Confirmed  Deaths  Recovered
# 0   Hong Kong  COVID-19        105       2         43
# 1       Macau  COVID-19         10       0          9
# 2      Taiwan  COVID-19         44       1         12
# 3         USA  COVID-19         45       0          0
# 4         USA  COVID-19          0       0          0
# ..        ...       ...        ...     ...        ...
# 62  Australia  COVID-19         10       0          7
# 63  Australia  COVID-19          3       1          0
# 64  Australia  COVID-19         13       0          8
# 65  Australia  COVID-19          5       0          2
# 66  Australia  COVID-19          0       0          0
#
# [67 rows x 7 columns]

# %% [markdown]
# ## Create Country-level nodes and relationships

# %%
load_country = f"LOAD CSV WITH HEADERS FROM 'file:///{data_dir}/country_COVID-19.csv' AS e"  
query = """  
MERGE (k:Country {name:e.Country})
SET k.location = point({longitude: toFloat(e.Long), latitude: toFloat(e.Lat)})
MERGE (o:InfectiousDiseaseOutbreak {name:e.Outbreak})
        
MERGE (o)-[i:OCCURED_IN {update:e.`Last Update`}]->(k)
SET i.confirmed = toInt(e.Confirmed),
    i.deaths = toInt(e.Deaths), 
    i.recovered = toInt(e.Recovered)
"""
graph.run(load_country + query)

# %% [markdown]
# #### Run a test query

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)-[l:OCCURED_IN]->(k:Country)
RETURN k.name as Country,k.location as Location, o.name as Outbreak, l.confirmed as Confirmed, l.deaths as Deaths, l.recovered as Recovered
"""
graph.run(query).to_data_frame()
# Out:
#         Country                                 Location  Outbreak  Confirmed  \
# 0          Iraq                             (44.0, 33.0)  COVID-19         35
# 1        Brazil                      (-51.9253, -14.235)  COVID-19          4
# 2   Philippines                            (122.0, 13.0)  COVID-19          3
# 3         China  (111.54290322580647, 33.40693612903225)  COVID-19      80422
# 4   Switzerland                        (8.2275, 46.8182)  COVID-19        114
# ..          ...                                      ...       ...        ...
# 85   Azerbaijan                       (47.5769, 40.1431)  COVID-19          6
# 86    Lithuania                       (23.8813, 55.1694)  COVID-19          1
# 87      Bahrain                         (50.55, 26.0275)  COVID-19         55
# 88         Iran                             (53.0, 32.0)  COVID-19       3513
# 89      Belarus                       (27.9534, 53.7098)  COVID-19          6
#
#     Deaths  Recovered
# 0        2          0
# 1        0          0
# 2        1          1
# 3     3013      52240
# 4        1          3
# ..     ...        ...
# 85       0          0
# 86       0          0
# 87       0          0
# 88     107        739
# 89       0          0
#
# [90 rows x 6 columns]

# %% [markdown]
# ### Create nodes SARS and MERS data
# To be added in the future

# %%
query = """
CREATE (s:InfectiousDiseaseOutbreak {name: 'SARS'})
CREATE (m:InfectiousDiseaseOutbreak {name: 'MERS'})
"""
graph.run(query)

# %%
query = """
MATCH (o:InfectiousDiseaseOutbreak)
RETURN o.name as Outbreak
"""
graph.run(query).to_data_frame()
# Out:
#    Outbreak
# 0      SARS
# 1      MERS
# 2  COVID-19

# %% [markdown]
# ### Add taxonomy data

# %%
query = """
MERGE (p: Pathogen{name: 'Wuhan seafood market pneumonia virus'})
SET p.taxonomyId = '269749'
MERGE (o:InfectiousDiseaseOutbreak {name: 'COVID-19'})

MERGE (p)-[:CAUSES]->(o)
"""
graph.run(query)

# %% [markdown]
# ### Add strain data at City level

# %%
load_strains_city = f"LOAD CSV WITH HEADERS FROM 'file:///{data_dir}/strains_city_COVID-19.csv' AS e" 
query = """  
MERGE (c:City {name:e.City})
MERGE (s:Strain {name:e.strain})
SET s.genbankId = e.genbank_accession
MERGE (p: Pathogen{name: 'Wuhan seafood market pneumonia virus'})
MERGE (o:InfectiousDiseaseOutbreak {name: '2019-nCoV'})
        
MERGE (s)-[:FOUND_IN]->(c)
MERGE (p)-[:HAS_STRAIN]->(s)
"""
graph.run(load_strains_city + query)

# %%
query = """
MATCH (s: Strain)-[:FOUND_IN]->(c:City)
RETURN c.name as City, s.name as Strain
"""
graph.run(query).to_data_frame()
# Out:
#                City          Strain
# 0       King County  USA/WA-S2/2020
# 1  Snohomish County    USA/WA1/2020
# 2  Snohomish County    USA/WA2/2020
# 3       Los Angeles    USA/CA1/2020
# 4     Orange County    USA/CA2/2020
# 5            Boston    USA/MA1/2020

# %% [markdown]
# ### Add strain data at State level

# %%
load_strains_country = f"LOAD CSV WITH HEADERS FROM 'file:///{data_dir}/strains_state_COVID-19.csv' AS e"  
query = """  
MERGE (st:State {name:e.State})
MERGE (s:Strain {name:e.strain})
MERGE (p: Pathogen{name: 'Wuhan seafood market pneumonia virus'})
MERGE (o:InfectiousDiseaseOutbreak {name: 'COVID-19'})
        
MERGE (s)-[:FOUND_IN]->(st)
MERGE (p)-[:HAS_STRAIN]->(s)
"""
graph.run(load_strains_country + query)

# %%
query = """
MATCH (s: Strain)-[:FOUND_IN]->(st:State)
RETURN st.name as State, s.name as Strain
"""
graph.run(query).to_data_frame()
# Out:
#                 State                       Strain
# 0              Fujian                Fujian/8/2020
# 1              Fujian               Fujian/13/2020
# 2           Guangdong  pangolin/Guangdong/P2S/2019
# 3           Guangdong       Guangzhou/20SF206/2020
# 4           Guangdong       Shenzhen/SZTH-004/2020
# ..                ...                          ...
# 132           Beijing     Beijing/IVDC-BJ-005/2020
# 133  British Columbia        Canada/BC_37_0-2/2020
# 134         Chongqing   Chongqing/IVDC-CQ-001/2020
# 135         Chongqing          Chongqing/YC01/2020
# 136         Chongqing          Chongqing/ZX01/2020
#
# [137 rows x 2 columns]

# %% [markdown]
# ### Add strain data at Country level

# %%
load_strains_country = f"LOAD CSV WITH HEADERS FROM 'file:///{data_dir}/strains_country_COVID-19.csv' AS e"
query = """  
MERGE (k:Country {name:e.Country})
MERGE (s:Strain {name:e.strain})
MERGE (p: Pathogen{name: 'Wuhan seafood market pneumonia virus'})
MERGE (o:InfectiousDiseaseOutbreak {name: 'COVID-19'})
        
MERGE (s)-[:FOUND_IN]->(k)
MERGE (p)-[:HAS_STRAIN]->(s)
"""
graph.run(load_strains_country + query)

# %%
query = """
MATCH (s: Strain)-[:FOUND_IN]->(k:Country)
RETURN k.name as Country, s.name as Strain, s.genbankId as GenbankId
"""
graph.run(query).to_data_frame()
# Out:
#        Country                    Strain GenbankId
# 0    Hong Kong  HongKong/VB20026565/2020      None
# 1    Hong Kong  HongKong/VM20001061/2020      None
# 2    Hong Kong  HongKong/VM20001988/2020      None
# 3       Taiwan             Taiwan/3/2020      None
# 4       Taiwan   Taiwan/CGMH-CGU-01/2020      None
# ..         ...                       ...       ...
# 204  Australia      Australia/NSW06/2020      None
# 205  Australia      Australia/QLD02/2020      None
# 206  Australia      Australia/QLD04/2020      None
# 207  Australia      Australia/NSW01/2020      None
# 208  Australia             Sydney/2/2020      None
#
# [209 rows x 3 columns]

# %%
query = """
MATCH (p: Pathogen)-[:HAS_STRAIN]-(s:Strain)
RETURN s.name as Strain
"""
graph.run(query).to_data_frame()
# Out:
#                                 Strain
# 0                    Korea/KCDC12/2020
# 1                 Japan/TY-WK-012/2020
# 2          Switzerland/1000477377/2020
# 3                  Brazil/SPBR-01/2020
# 4    Germany/Baden-Wuerttemberg-1/2020
# ..                                 ...
# 204           Wuhan/IPBCAMS-WH-05/2020
# 205               Australia/VIC01/2020
# 206        pangolin/Guangdong/P2S/2019
# 207                   China/WH-09/2020
# 208                Foshan/20SF210/2020
#
# [209 rows x 1 columns]
